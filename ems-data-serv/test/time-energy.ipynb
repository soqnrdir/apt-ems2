# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('time_energy.csv', sep=',',  index_col=['Time'], parse_dates=True, dayfirst=True)

# %%
df.head()
# Out:
#                      Date & Time       Energy
# Time
# 2021-07-19 16:06:00   1626710760  3989.351952
# 2021-07-19 16:07:00   1626710820  3989.357041
# 2021-07-19 16:08:00   1626710880  3989.362111
# 2021-07-19 16:09:00   1626710940  3989.367271
# 2021-07-19 16:10:00   1626711000  3989.372429

# %%
df.dtypes
# Out:
# Date & Time      int64
# Energy         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 57600 entries, 2021-07-19 16:06:00 to 2021-08-28 16:05:00
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date & Time  57600 non-null  int64
#  1   Energy       57600 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 1.3 MB

# %%
df['Delta'] = df['Energy'].diff()

# %%
df.head()
# Out:
#                      Date & Time       Energy     Delta
# Time
# 2021-07-19 16:06:00   1626710760  3989.351952       NaN
# 2021-07-19 16:07:00   1626710820  3989.357041  0.005089
# 2021-07-19 16:08:00   1626710880  3989.362111  0.005069
# 2021-07-19 16:09:00   1626710940  3989.367271  0.005160
# 2021-07-19 16:10:00   1626711000  3989.372429  0.005158

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57600 entries, 2021-07-19 16:06:00 to 2021-08-28 16:05:00
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date & Time  57600 non-null  int64
#  1   Energy       57600 non-null  float64
#  2   Delta        57599 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 1.8+ MB

# %%
df[['Energy']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df[['Delta']].plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
df.head()
# Out:
#                      Date & Time       Energy     Delta
# Time
# 2021-07-19 16:06:00   1626710760  3989.351952       NaN
# 2021-07-19 16:07:00   1626710820  3989.357041  0.005089
# 2021-07-19 16:08:00   1626710880  3989.362111  0.005069
# 2021-07-19 16:09:00   1626710940  3989.367271  0.005160
# 2021-07-19 16:10:00   1626711000  3989.372429  0.005158

# %%
#df2 = df.resample('5H')
dfD = df.resample('1D').last()
dfD['Delta'] = dfD['Energy'].diff()
dfD
# Out:
#             Date & Time       Energy      Delta
# Time
# 2021-07-19   1626739140  3992.393598        NaN
# 2021-07-20   1626825540  4009.535769  17.142171
# 2021-07-21   1626911940  4030.693842  21.158073
# 2021-07-22   1626998340  4047.588506  16.894664
# 2021-07-23   1627084740  4068.098821  20.510315
# 2021-07-24   1627171140  4074.259188   6.160367
# 2021-07-25   1627257540  4083.658077   9.398889
# 2021-07-26   1627343940  4102.568133  18.910056
# 2021-07-27   1627430340  4126.279144  23.711010
# 2021-07-28   1627516740  4145.023280  18.744136
# 2021-07-29   1627603140  4162.809307  17.786027
# 2021-07-30   1627689540  4179.677581  16.868274
# 2021-07-31   1627775940  4185.983165   6.305584
# 2021-08-01   1627862340  4193.067148   7.083983
# 2021-08-02   1627948740  4209.232397  16.165249
# 2021-08-03   1628035140  4225.266894  16.034497
# 2021-08-04   1628121540  4231.350497   6.083603
# 2021-08-05   1628207940  4237.488392   6.137896
# ...

# %%
dfD[['Delta']].plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
dfD[['Delta']].plot.bar(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# 중간에 데이터가 빠졌을때  해당 빠진 시간대 데이터가 resample에 들어가는지 여부 확인

# %%
dfH = df.resample('1H').last()
dfH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 961 entries, 2021-07-19 16:00:00 to 2021-08-28 16:00:00
# Freq: H
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date & Time  961 non-null    int64
#  1   Energy       961 non-null    float64
#  2   Delta        961 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 30.0 KB

# %%
dfH.drop(dfH.index[500:800], inplace=True)

# %%
df_test = dfH.resample('1D').last()

# %%
df_test['Delta'] = df_test['Energy'].diff()

# %%
df_test
# Out:
#              Date & Time       Energy      Delta
# Time
# 2021-07-19  1.626739e+09  3992.393598        NaN
# 2021-07-20  1.626826e+09  4009.535769  17.142171
# 2021-07-21  1.626912e+09  4030.693842  21.158073
# 2021-07-22  1.626998e+09  4047.588506  16.894664
# 2021-07-23  1.627085e+09  4068.098821  20.510315
# 2021-07-24  1.627171e+09  4074.259188   6.160367
# 2021-07-25  1.627258e+09  4083.658077   9.398889
# 2021-07-26  1.627344e+09  4102.568133  18.910056
# 2021-07-27  1.627430e+09  4126.279144  23.711010
# 2021-07-28  1.627517e+09  4145.023280  18.744136
# 2021-07-29  1.627603e+09  4162.809307  17.786027
# 2021-07-30  1.627690e+09  4179.677581  16.868274
# 2021-07-31  1.627776e+09  4185.983165   6.305584
# 2021-08-01  1.627862e+09  4193.067148   7.083983
# 2021-08-02  1.627949e+09  4209.232397  16.165249
# 2021-08-03  1.628035e+09  4225.266894  16.034497
# 2021-08-04  1.628122e+09  4231.350497   6.083603
# 2021-08-05  1.628208e+09  4237.488392   6.137896
# ...

# %%
df_test[['Delta']].plot.bar(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Time'>
